# %%
from sympy import Function, dsolve, Eq

v = Function('Vin')
edo = Eq(v(t).diff(t) + v(t), cos(t))
solucao = dsolve(edo, v(t))
print("\nSolução da EDO:")
display(solucao)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 from sympy import Function, dsolve, Eq
#       2
#       3 v = Function('Vin')
# ----> 4 edo = Eq(v(t).diff(t) + v(t), cosh(t))
#       5 solucao = dsolve(edo, v(t))
#       6 print("\nSolução da EDO:")
#       7 display(solucao)
#
# NameError: name 'cosh' is not defined
